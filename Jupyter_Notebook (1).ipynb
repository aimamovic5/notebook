# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# <b> Name: Adnan Imamović </b> <br>
# Bachelor of Science Degree in Automatic Control and Electronics at the Faculty of Electrical Engineering, University of Sarajevo, Bosnia and Herzegovina

# %% [markdown]
# <em> I am interested in Data Science because I love to find meaning behind phenomenons and numbers. I also love data visualization and I enjoy looking at data charts.</em>

# %% [markdown]
# <h3> The following code is supposed to display the sentence "I love Data" borderlined with asterisks.

# %%
for x in range(0, 14):
    print("*", end="")
print("\n*", end="")
print("I love Data!",end="")
print("*")
for x in range(0,14):
    print("*", end="")
# Out:
# **************
# *I love Data!*
# **************

# %% [markdown]
# <h1> Bosnian Football League </h1>
# <img src="https://upload.wikimedia.org/wikipedia/en/8/82/Mtel_Premijer_Liga.png" alt = "Official Logo">
#
# In the next few sentences I will introduce you to Bosnian football league. The league is officialy named Premier league of Bosnia and Herzegovina, and it contains 12 football teams. Current champions are Zrinjski Mostar, and the Cup winner are Velež Mostar. <hr> Both clubs come from Mostar, a beautiful town known by its stone-made Old Bridge built in 16th century. The bridge was destroyed by HVO, a Croatian Army, in 1993, during the war in Bosnia. It was rebuilt in 2004. </hr>
# The most successful club is FK Sarajevo.
# Here is the current ranking table:
# <table>
#     <tr>
#         <th>Position</th>
#         <th>Club</th>
#         <th>Points</th>
#     </tr>
#     <tr>
#         <th>
#             <ol>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#                 <li> </li>
#             </ol>
#         </th>
#         <th>
#             <ul>
#                 <li> Široki Brijeg </li>
#                 <li> Sloga Doboj</li>
#                 <li> Željezničar</li>
#                 <li> Sarajevo</li>
#                 <li> Velež Mostar</li>
#                 <li> Posušje</li>
#                 <li> Borac Banja Luka</li>
#                 <li> Leotar</li>
#                 <li> Tuzla City</li>
#                 <li> Zrinjski</li>
#                 <li> Igman Konjic</li>
#                 <li> Sloboda</li>
#             </ul>
#         </th>
#         <th>
#             <ul>
#                 <li> 6 </li>
#                 <li> 4</li>
#                 <li> 4</li>
#                 <li> 3</li>
#                 <li> 1</li>
#                 <li> 1</li>
#                 <li> 1</li>
#                 <li> 1</li>
#                 <li> 0</li>
#                 <li> 0</li>
#                 <li> 0</li>
#                 <li> 0</li>
#             </ul>
#         </th>
# </table>
#
# If you are interested in knowing more about Bosnian football, you can check it on Wikipedia: <a href="https://en.wikipedia.org/wiki/Premier_League_of_Bosnia_and_Herzegovina"> Premier League of Bosnia and Herzegovina </a>
